# %%
from centrex_tlf_hamiltonian import states, hamiltonian
import centrex_tlf_couplings as couplings

import numpy as np
from matplotlib import cm
import matplotlib.pyplot as plt

# %%
plt.rcParams.update({'font.size': 15})

# %%
qn_select = states.QuantumSelector(J=1)
ground_states = states.generate_coupled_states_X(qn_select)

# %%
qn_select = states.QuantumSelector(J=1, F1=1 / 2, F=1, P=1, Ω=1)
excited_states = states.generate_coupled_states_B(qn_select)

# %%
reduced_hamiltonian = hamiltonian.generate_total_reduced_hamiltonian(
    X_states_approx=ground_states,
    B_states_approx=excited_states,   
)

# %%
field = couplings.generate_coupling_field_automatic(
    ground_states_approx=1*ground_states,
    excited_states_approx=1*excited_states,
    QN_basis = list(1*ground_states) + list(1*excited_states),
    H_rot = reduced_hamiltonian.H_int,
    QN = reduced_hamiltonian.QN,
    V_ref = reduced_hamiltonian.V_ref_int,
    pol_vecs = [
        couplings.polarization_σp.vector,
        couplings.polarization_σm.vector
    ],

)

# %%
field
# Out:
# CouplingFields(ground_main=|X, J = 1, F₁ = 3/2, F = 2, mF = 0, P = -, Ω = 0>, excited_main=|B, J = 1, F₁ = 1/2, F = 1, mF = 1, P = +, Ω = 1>, main_coupling=1.70e-01+0.00e+00j

# %%
dfs = couplings.generate_coupling_dataframe(field, reduced_hamiltonian.QN)

# %%
for df in dfs:
    display(df)
# Out:
#                                   ground  \
# 0    |X, J = 1, F₁ = 1/2, F = 0, mF = 0>
# 1   |X, J = 1, F₁ = 1/2, F = 1, mF = -1>
# 2    |X, J = 1, F₁ = 1/2, F = 1, mF = 0>
# 3   |X, J = 1, F₁ = 3/2, F = 1, mF = -1>
# 4   |X, J = 1, F₁ = 3/2, F = 1, mF = -1>
# 5    |X, J = 1, F₁ = 3/2, F = 1, mF = 0>
# 6    |X, J = 1, F₁ = 3/2, F = 1, mF = 0>
# 7   |X, J = 1, F₁ = 3/2, F = 2, mF = -2>
# 8   |X, J = 1, F₁ = 3/2, F = 2, mF = -2>
# 9   |X, J = 1, F₁ = 3/2, F = 2, mF = -1>
# 10  |X, J = 1, F₁ = 3/2, F = 2, mF = -1>
# 11   |X, J = 1, F₁ = 3/2, F = 2, mF = 0>
# 12   |X, J = 1, F₁ = 3/2, F = 2, mF = 1>
#
#                                  excited           couplings
# 0    |B, J = 1, F₁ = 1/2, F = 1, mF = 1> -0.467636+0.000000j
# 1    |B, J = 1, F₁ = 1/2, F = 1, mF = 0>  0.457780+0.000000j
# 2    |B, J = 1, F₁ = 1/2, F = 1, mF = 1>  0.457780+0.000000j
# 3    |B, J = 1, F₁ = 1/2, F = 1, mF = 0> -0.192484+0.000000j
# 4    |B, J = 1, F₁ = 1/2, F = 1, mF = 1>  0.001473+0.000000j
# 5    |B, J = 1, F₁ = 1/2, F = 1, mF = 0> -0.001473+0.000000j
# 6    |B, J = 1, F₁ = 1/2, F = 1, mF = 1> -0.192484+0.000000j
# 7   |B, J = 1, F₁ = 1/2, F = 1, mF = -1>  0.415659+0.000000j
# 8    |B, J = 1, F₁ = 1/2, F = 1, mF = 0>  0.000884+0.000000j
# 9   |B, J = 1, F₁ = 1/2, F = 1, mF = -1> -0.001250+0.000000j
# 10   |B, J = 1, F₁ = 1/2, F = 1, mF = 0>  0.293914+0.000000j
# 11   |B, J = 1, F₁ = 1/2, F = 1, mF = 1>  0.169693+0.000000j
# 12   |B, J = 1, F₁ = 1/2, F = 1, mF = 0>  0.000797+0.000000j
#                                   ground  \
# 0    |X, J = 1, F₁ = 1/2, F = 0, mF = 0>
# 1    |X, J = 1, F₁ = 1/2, F = 1, mF = 0>
# 2    |X, J = 1, F₁ = 1/2, F = 1, mF = 1>
# 3   |X, J = 1, F₁ = 3/2, F = 1, mF = -1>
# 4    |X, J = 1, F₁ = 3/2, F = 1, mF = 0>
# 5    |X, J = 1, F₁ = 3/2, F = 1, mF = 1>
# 6   |X, J = 1, F₁ = 3/2, F = 2, mF = -1>
# 7    |X, J = 1, F₁ = 3/2, F = 2, mF = 0>
# 8    |X, J = 1, F₁ = 3/2, F = 2, mF = 1>
# 9    |X, J = 1, F₁ = 3/2, F = 2, mF = 1>
# 10   |X, J = 1, F₁ = 3/2, F = 2, mF = 2>
# 11   |X, J = 1, F₁ = 3/2, F = 2, mF = 2>
#
#                                  excited           couplings
# 0   |B, J = 1, F₁ = 1/2, F = 1, mF = -1>  0.467636+0.000000j
# 1   |B, J = 1, F₁ = 1/2, F = 1, mF = -1>  0.457780+0.000000j
# 2    |B, J = 1, F₁ = 1/2, F = 1, mF = 0>  0.457781+0.000000j
# 3   |B, J = 1, F₁ = 1/2, F = 1, mF = -1>  0.001473+0.000000j
# 4   |B, J = 1, F₁ = 1/2, F = 1, mF = -1> -0.192484+0.000000j
# 5    |B, J = 1, F₁ = 1/2, F = 1, mF = 0> -0.192493+0.000000j
# 6    |B, J = 1, F₁ = 1/2, F = 1, mF = 0>  0.000798+0.000000j
# 7   |B, J = 1, F₁ = 1/2, F = 1, mF = -1> -0.169693+0.000000j
# 8    |B, J = 1, F₁ = 1/2, F = 1, mF = 0> -0.293869+0.000000j
# 9    |B, J = 1, F₁ = 1/2, F = 1, mF = 1> -0.007437+0.000000j
# 10   |B, J = 1, F₁ = 1/2, F = 1, mF = 0>  0.005259+0.000000j
# 11   |B, J = 1, F₁ = 1/2, F = 1, mF = 1> -0.415594+0.000000j

# %%
z = np.abs(field.fields[0].field)
z[z == 0] = np.nan

custom_string = ["electronic", "J", "F1", "F", "mF"]

fig, ax = plt.subplots(figsize = (8,6))

c = ax.imshow(z)
cbar = fig.colorbar(c)

ax.set_xticks(np.arange(len(z)))
ax.set_yticks(np.arange(len(z)))
ax.set_xticklabels(
    [qn.largest.state_string_custom(custom_string) for qn in reduced_hamiltonian.QN],
    rotation='vertical'
)
ax.set_yticklabels(
    [qn.largest.state_string_custom(custom_string) for qn in reduced_hamiltonian.QN]
)
ax.set_xticks(np.arange(len(z)+1)-0.5, minor=True)
ax.set_yticks(np.arange(len(z)+1)-0.5, minor=True)
ax.grid(which='minor', linestyle='-', linewidth=2)
